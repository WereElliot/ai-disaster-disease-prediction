# %% [markdown]
# # Phase 2: Exploratory Data Analysis - Data Overview
# This notebook provides a summary of the processed dataset, including descriptive statistics and missing value analysis.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import sys

# Ensure project root is in path
sys.path.append(os.path.abspath('..'))
from src.utils.config import load_config

config = load_config('../config.yaml')
processed_path = Path('..') / config['data']['paths']['processed'] / 'final_dataset.parquet'
df = pd.read_parquet(processed_path)
df.head()

# %% [markdown]
# ## 1. Summary Statistics

# %%
print("Shape of dataset:", df.shape)
df.describe()

# %% [markdown]
# ## 2. Missing Values Analysis

# %%
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values[missing_values > 0])
