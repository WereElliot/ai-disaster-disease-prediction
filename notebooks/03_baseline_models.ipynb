# %% [markdown]
# # Phase 2: Baseline Modeling
# Implementation and evaluation of simple statistical and machine learning baselines.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import sys

# Ensure project root is in path
sys.path.append(os.path.abspath('..'))
from src.utils.config import load_config
from src.models.baseline import evaluate_baselines

config = load_config('../config.yaml')
processed_path = Path('..') / config['data']['paths']['processed'] / 'final_dataset.parquet'
df = pd.read_parquet(processed_path)
df.head()

# %% [markdown]
# ## 1. Baseline Evaluation

# %%
metrics = evaluate_baselines(df, target='cases')
print("Baseline Metrics:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")
